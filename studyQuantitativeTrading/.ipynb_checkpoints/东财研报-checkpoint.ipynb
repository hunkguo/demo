# %%
import json
from datetime import datetime

import requests

report_list = []


def get_all_bk_code(bkCode='016'):
    today = datetime.now().timestamp()
    url = 'http://reportapi.eastmoney.com/report/bk?bkCode=' + bkCode + '&_=' + str(today)
    resp = requests.get(url).text
    data = json.loads(resp)
    all_bk_info = data['data']
    #print(all_bk_info)
    return all_bk_info


def get_single_trades_info(bk_code='737', from_date=None):
    today = datetime.now().timestamp()
    from_date = '2020-12-14'
    end_date = datetime.now().strftime('%Y-%m-%d')
    url = 'http://reportapi.eastmoney.com/report/list' \
          '?industryCode=' + str(bk_code) \
          + '&pageSize=50' \
            '&industry=' \
            '&rating=' \
            '&ratingChange=*' \
            '&beginTime=' + from_date \
          + '&endTime=' + end_date \
          + '&pageNo=1' \
            '&fields=&' \
            'qType=0' \
            '&orgCode=' \
            '&rcode=&_=' + str(today)
    # qType: 必填，0标识查询个股研报，1标识行业研报，3 标识宏观研究报告
    resp = requests.get(url).text
    data = json.loads(resp)['data']
    #print(data)
    return data


def get_single_report(report_info):
    url = 'http://pdf.dfcfw.com/pdf/H3_' + str(report_info['infoCode']) + '_1.pdf'
    #print('%s: %s' % (report_info['title'], url))
    report = {'title': report_info['title'], 'url': url}
    report_list.append(report)
    with open('reports.json', 'a') as file:
        file.write('{' + 'title' + report_info['title'] + '; url:' + url + '}\n')

# %%
def get_all_report():
    bk_list = ['020', '016', '007']
    for bk in bk_list:
        all_bk_info = get_all_bk_code(bk)
        for e in all_bk_info:
            bk_list = get_single_trades_info(e['bkCode'])
            for info in bk_list:
                get_single_report(info)


#get_all_report()

# %%
bk_list = ['020', '016', '007']
reportCount = 0
for bk in bk_list:
    all_bk_info = get_all_bk_code(bk)
    #print(all_bk_info)

    for e in all_bk_info:
        bk_list = get_single_trades_info(e['bkCode'])
        if len(bk_list)>0:
            print(bk_list)
            reportCount = reportCount+1
print(str(reportCount))
# Out:
# [{'title': '市场份额提升趋势确定性高；上调盈利预测及目标价', 'stockName': '恒立液压', 'stockCode': '601100', 'orgCode': '80027629', 'orgName': '招银国际证券有限公司', 'orgSName': '招银国际', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439900691', 'column': '002004001003', 'predictNextTwoYearEps': '2.4500000000', 'predictNextTwoYearPe': '', 'predictNextYearEps': '2.1100000000', 'predictNextYearPe': '55.0000000000', 'predictThisYearEps': '1.6700000000', 'predictThisYearPe': '', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '545', 'indvInduName': '机械行业', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '', 'lastEmRatingValue': '', 'lastEmRatingName': '', 'ratingChange': 0, 'reportType': 2, 'author': ['11000259551.冯键嵘'], 'indvIsNew': '001', 'researcher': '冯键嵘', 'newListingDate': '2011-10-28 00:00:00.000', 'newPurchaseDate': '2011-10-19 00:00:00.0', 'newIssuePrice': 23.0, 'newPeIssueA': 42.59, 'indvAimPriceT': '114.4000000000', 'indvAimPriceL': '114.4000000000', 'attachType': '0', 'attachSize': 883, 'attachPages': 3, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cK2IJUzhYHXhGc7aYyu2iWM=', 'sRatingName': '买入', 'sRatingCode': '0101', 'market': 'SHANGHAI', 'authorID': ['11000259551'], 'count': 3, 'orgType': 'gray'}, {'title': '焊接与切割设备小巨人，航空航天制造业务始发力', 'stockName': '上海沪工', 'stockCode': '603131', 'orgCode': '80084302', 'orgName': '安信证券股份有限公司', 'orgSName': '安信证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439854901', 'column': '002004001002', 'predictNextTwoYearEps': '1.3200000000', 'predictNextTwoYearPe': '19.8000000000', 'predictNextYearEps': '0.8500000000', 'predictNextYearPe': '31.0000000000', 'predictThisYearEps': '0.5400000000', 'predictThisYearPe': '48.8000000000', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '545', 'indvInduName': '机械行业', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '', 'lastEmRatingValue': '', 'lastEmRatingName': '', 'ratingChange': 0, 'reportType': 2, 'author': ['11000173747.冯福章', '11000344832.花超'], 'indvIsNew': '001', 'researcher': '冯福章,花超', 'newListingDate': '2016-06-07 00:00:00.000', 'newPurchaseDate': '2016-05-26 00:00:00.0', 'newIssuePrice': 10.09, 'newPeIssueA': 22.98, 'indvAimPriceT': '', 'indvAimPriceL': '', 'attachType': '0', 'attachSize': 1950, 'attachPages': 19, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cAfJQJWk/PIPYqUuIAvyagI=', 'sRatingName': '买入', 'sRatingCode': '0104', 'market': 'SHANGHAI', 'authorID': ['11000173747', '11000344832'], 'count': 2, 'orgType': 'white'}]
# [{'title': '计量检测行业龙头，成长性凸显', 'stockName': '广电计量', 'stockCode': '002967', 'orgCode': '80050806', 'orgName': '太平洋证券股份有限公司', 'orgSName': '太平洋', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439854898', 'column': '002004006001', 'predictNextTwoYearEps': '0.8000000000', 'predictNextTwoYearPe': '35.0000000000', 'predictNextYearEps': '0.6000000000', 'predictNextYearPe': '48.0000000000', 'predictThisYearEps': '0.4000000000', 'predictThisYearPe': '72.0000000000', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '539', 'indvInduName': '综合行业', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '', 'lastEmRatingValue': '', 'lastEmRatingName': '', 'ratingChange': 2, 'reportType': 2, 'author': ['11000178999.刘国清', '11000261931.曾博文'], 'indvIsNew': '001', 'researcher': '刘国清,曾博文', 'newListingDate': '2019-11-08 00:00:00.000', 'newPurchaseDate': '2019-10-30 00:00:00.0', 'newIssuePrice': 7.43, 'newPeIssueA': 22.99, 'indvAimPriceT': '', 'indvAimPriceL': '', 'attachType': '0', 'attachSize': 611, 'attachPages': 5, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cFRxJ7MlHJWW/S4fbxGJOg4=', 'sRatingName': '买入', 'sRatingCode': '0105', 'market': 'SHENZHEN', 'authorID': ['11000178999', '11000261931'], 'count': 1, 'orgType': 'gray'}, {'title': '教育培训成核心业务，异地复制打开成长空间', 'stockName': '科德教育', 'stockCode': '300192', 'orgCode': '80000140', 'orgName': '财信证券有限责任公司', 'orgSName': '财信证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439818186', 'column': '002004001002', 'predictNextTwoYearEps': '0.8900000000', 'predictNextTwoYearPe': '18.6000000000', 'predictNextYearEps': '0.6900000000', 'predictNextYearPe': '23.8000000000', 'predictThisYearEps': '0.5400000000', 'predictThisYearPe': '30.5000000000', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '539', 'indvInduName': '综合行业', 'emRatingCode': '006', 'emRatingValue': '2', 'emRatingName': '增持', 'lastEmRatingCode': '', 'lastEmRatingValue': '', 'lastEmRatingName': '', 'ratingChange': 2, 'reportType': 2, 'author': ['11000236021.杨甫', '11000332141.曹俊杰'], 'indvIsNew': '001', 'researcher': '杨甫,曹俊杰', 'newListingDate': '2011-03-22 00:00:00.000', 'newPurchaseDate': '2011-03-14 00:00:00.0', 'newIssuePrice': 22.82, 'newPeIssueA': 49.02, 'indvAimPriceT': '', 'indvAimPriceL': '', 'attachType': '0', 'attachSize': 1813, 'attachPages': 22, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cGiPQEnOHsbWst1Z+2F7c7Y=', 'sRatingName': '谨慎推荐', 'sRatingCode': '0202', 'market': 'SHENZHEN', 'authorID': ['11000236021', '11000332141'], 'count': 1, 'orgType': 'gray'}]
# [{'title': '御家汇点评报告：PE股东减持近尾声，高增长持续兑现', 'stockName': '御家汇', 'stockCode': '300740', 'orgCode': '80000206', 'orgName': '浙商证券股份有限公司', 'orgSName': '浙商证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439870492', 'column': '002004006001', 'predictNextTwoYearEps': '0.8500000000', 'predictNextTwoYearPe': '18.0000000000', 'predictNextYearEps': '0.5700000000', 'predictNextYearPe': '27.0000000000', 'predictThisYearEps': '0.2900000000', 'predictThisYearPe': '52.0000000000', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '538', 'indvInduName': '化工行业', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '007', 'lastEmRatingValue': '3', 'lastEmRatingName': '买入', 'ratingChange': 3, 'reportType': 2, 'author': ['11000255938.陈腾曦'], 'indvIsNew': '001', 'researcher': '陈腾曦', 'newListingDate': '2018-02-08 00:00:00.000', 'newPurchaseDate': '2018-01-30 00:00:00.0', 'newIssuePrice': 21.23, 'newPeIssueA': 22.99, 'indvAimPriceT': '', 'indvAimPriceL': '', 'attachType': '0', 'attachSize': 1207, 'attachPages': 7, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cL9U5d4Oe0pZayTkMXqae6U=', 'sRatingName': '买入', 'sRatingCode': '0103', 'market': 'SHENZHEN', 'authorID': ['11000255938'], 'count': 1, 'orgType': 'white'}]
# [{'title': '发展基础逐步夯实，产能释放助力公司快速发展', 'stockName': '钢研高纳', 'stockCode': '300034', 'orgCode': '80000135', 'orgName': '中国银河证券股份有限公司', 'orgSName': '中国银河', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439820462', 'column': '002004006003', 'predictNextTwoYearEps': '0.6400000000', 'predictNextTwoYearPe': '44.0000000000', 'predictNextYearEps': '0.5000000000', 'predictNextYearPe': '56.0000000000', 'predictThisYearEps': '0.4100000000', 'predictThisYearPe': '69.0000000000', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '537', 'indvInduName': '材料行业', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '007', 'lastEmRatingValue': '3', 'lastEmRatingName': '买入', 'ratingChange': 3, 'reportType': 2, 'author': ['11000196552.李良'], 'indvIsNew': '001', 'researcher': '李良', 'newListingDate': '2009-12-25 00:00:00.000', 'newPurchaseDate': '2009-12-16 00:00:00.0', 'newIssuePrice': 19.53, 'newPeIssueA': 65.1, 'indvAimPriceT': '', 'indvAimPriceL': '', 'attachType': '0', 'attachSize': 637, 'attachPages': 3, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cPzvSqI2dnfyBAt4vEZ0MT4=', 'sRatingName': '推荐', 'sRatingCode': '0104', 'market': 'SHENZHEN', 'authorID': ['11000196552'], 'count': 3, 'orgType': 'gray'}]
# [{'title': '技术积淀雄厚，软包放量在即', 'stockName': '孚能科技', 'stockCode': '688567', 'orgCode': '80092742', 'orgName': '信达证券股份有限公司', 'orgSName': '信达证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439854928', 'column': '002004001002', 'predictNextTwoYearEps': '0.8000000000', 'predictNextTwoYearPe': '39.8700000000', 'predictNextYearEps': '0.3500000000', 'predictNextYearPe': '92.2900000000', 'predictThisYearEps': '-0.1800000000', 'predictThisYearPe': '', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '481', 'indvInduName': '汽车行业', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '', 'lastEmRatingValue': '', 'lastEmRatingName': '', 'ratingChange': 2, 'reportType': 2, 'author': ['11000331534.武浩', '11000277040.陈磊'], 'indvIsNew': '001', 'researcher': '武浩,陈磊', 'newListingDate': '2020-07-17 00:00:00.000', 'newPurchaseDate': '2020-07-06 00:00:00.0', 'newIssuePrice': 15.9, 'newPeIssueA': 1737.49, 'indvAimPriceT': '', 'indvAimPriceL': '', 'attachType': '0', 'attachSize': 1123, 'attachPages': 29, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cAP9nbb/EkRTtnjcOQiAi1s=', 'sRatingName': '买入', 'sRatingCode': '0101', 'market': 'SHANGHAI', 'authorID': ['11000331534', '11000277040'], 'count': 3, 'orgType': 'gray'}, {'title': '事件点评：百炼收购完成，成就全球铝铸龙头企业', 'stockName': '文灿股份', 'stockCode': '603348', 'orgCode': '80000038', 'orgName': '民生证券股份有限公司', 'orgSName': '民生证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439820461', 'column': '002004006003', 'predictNextTwoYearEps': '1.6100000000', 'predictNextTwoYearPe': '17.4000000000', 'predictNextYearEps': '1.2000000000', 'predictNextYearPe': '23.3000000000', 'predictThisYearEps': '0.4800000000', 'predictThisYearPe': '58.5000000000', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '481', 'indvInduName': '汽车行业', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '007', 'lastEmRatingValue': '3', 'lastEmRatingName': '买入', 'ratingChange': 3, 'reportType': 2, 'author': ['11000250834.邓健全', '11000283032.王静姝', '11000326136.庄延'], 'indvIsNew': '001', 'researcher': '邓健全,王静姝,庄延', 'newListingDate': '2018-04-26 00:00:00.000', 'newPurchaseDate': '2018-04-16 00:00:00.0', 'newIssuePrice': 15.26, 'newPeIssueA': 22.99, 'indvAimPriceT': '', 'indvAimPriceL': '', 'attachType': '0', 'attachSize': 903, 'attachPages': 5, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cI2ZTaeu0ez3KRKHDvZf4fs=', 'sRatingName': '推荐', 'sRatingCode': '0201', 'market': 'SHANGHAI', 'authorID': ['11000250834', '11000283032', '11000326136'], 'count': 1, 'orgType': 'gray'}]
# [{'title': '钛矿供需格局优化，龙头持续受益', 'stockName': '安宁股份', 'stockCode': '002978', 'orgCode': '80000073', 'orgName': '华泰证券股份有限公司', 'orgSName': '华泰证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439779720', 'column': '002004001002', 'predictNextTwoYearEps': '3.0500000000', 'predictNextTwoYearPe': '', 'predictNextYearEps': '2.6800000000', 'predictNextYearPe': '21.0000000000', 'predictThisYearEps': '1.9200000000', 'predictThisYearPe': '', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '479', 'indvInduName': '钢铁行业', 'emRatingCode': '006', 'emRatingValue': '2', 'emRatingName': '增持', 'lastEmRatingCode': '', 'lastEmRatingValue': '', 'lastEmRatingName': '', 'ratingChange': 2, 'reportType': 2, 'author': ['11000175326.刘曦', '11000300635.庄汀洲', '11000257762.邱瀚萱', '11000335133.龚润华'], 'indvIsNew': '001', 'researcher': '刘曦,庄汀洲,邱瀚萱,龚润华', 'newListingDate': '2020-04-17 00:00:00.000', 'newPurchaseDate': '2020-04-08 00:00:00.0', 'newIssuePrice': 27.47, 'newPeIssueA': 21.77, 'indvAimPriceT': '56.2800000000', 'indvAimPriceL': '56.2800000000', 'attachType': '0', 'attachSize': 2404, 'attachPages': 21, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cGTPkcmLnBQUphhSY12nuu4=', 'sRatingName': '增持', 'sRatingCode': '0302', 'market': 'SHENZHEN', 'authorID': ['11000175326', '11000300635', '11000257762', '11000335133'], 'count': 1, 'orgType': 'white'}]
# [{'title': '公司首次覆盖报告：显著低估的高成长铝材加工龙头', 'stockName': '明泰铝业', 'stockCode': '601677', 'orgCode': '80000162', 'orgName': '开源证券股份有限公司', 'orgSName': '开源证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439873380', 'column': '002004001002', 'predictNextTwoYearEps': '2.3600000000', 'predictNextTwoYearPe': '5.6000000000', 'predictNextYearEps': '2.0200000000', 'predictNextYearPe': '6.5000000000', 'predictThisYearEps': '1.6900000000', 'predictThisYearPe': '7.8000000000', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '478', 'indvInduName': '有色金属', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '', 'lastEmRatingValue': '', 'lastEmRatingName': '', 'ratingChange': 2, 'reportType': 2, 'author': ['11000239427.赖福洋'], 'indvIsNew': '001', 'researcher': '赖福洋', 'newListingDate': '2011-09-19 00:00:00.000', 'newPurchaseDate': '2011-09-07 00:00:00.0', 'newIssuePrice': 20.0, 'newPeIssueA': 33.33, 'indvAimPriceT': '', 'indvAimPriceL': '', 'attachType': '0', 'attachSize': 2695, 'attachPages': 36, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cP3x+LR8NsCtN/JmVFUcyak=', 'sRatingName': '买入( Buy)', 'sRatingCode': '0201', 'market': 'SHANGHAI', 'authorID': ['11000239427'], 'count': 1, 'orgType': 'gray'}]
# [{'title': '临时股东大会点评：春节具备信心，技改利在未来', 'stockName': '古井贡酒', 'stockCode': '000596', 'orgCode': '80000202', 'orgName': '华创证券有限责任公司', 'orgSName': '华创证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439779711', 'column': '002004006003', 'predictNextTwoYearEps': '7.2400000000', 'predictNextTwoYearPe': '33.0000000000', 'predictNextYearEps': '5.6900000000', 'predictNextYearPe': '42.0000000000', 'predictThisYearEps': '4.3000000000', 'predictThisYearPe': '55.0000000000', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '477', 'indvInduName': '酿酒行业', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '007', 'lastEmRatingValue': '3', 'lastEmRatingName': '买入', 'ratingChange': 3, 'reportType': 2, 'author': ['11000256934.欧阳予', '11000172896.董广阳'], 'indvIsNew': '001', 'researcher': '欧阳予,董广阳', 'newListingDate': '1996-09-27 00:00:00.000', 'newPurchaseDate': '1996-09-02 00:00:00.0', 'newIssuePrice': 8.48, 'newPeIssueA': '', 'indvAimPriceT': '310.0000000000', 'indvAimPriceL': '310.0000000000', 'attachType': '0', 'attachSize': 801, 'attachPages': 6, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cKkGK1HbB/DJWFjcsczWbO0=', 'sRatingName': '强推', 'sRatingCode': '0104', 'market': 'SHENZHEN', 'authorID': ['11000256934', '11000172896'], 'count': 11, 'orgType': 'gray'}, {'title': '扩产志在长远，十四五冲刺两百亿', 'stockName': '古井贡酒', 'stockCode': '000596', 'orgCode': '80000157', 'orgName': '中泰证券股份有限公司', 'orgSName': '中泰证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439779709', 'column': '002004001003', 'predictNextTwoYearEps': '6.9100000000', 'predictNextTwoYearPe': '34.0000000000', 'predictNextYearEps': '5.6500000000', 'predictNextYearPe': '42.0000000000', 'predictThisYearEps': '4.4200000000', 'predictThisYearPe': '54.0000000000', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '477', 'indvInduName': '酿酒行业', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '007', 'lastEmRatingValue': '3', 'lastEmRatingName': '买入', 'ratingChange': 3, 'reportType': 2, 'author': ['11000236946.范劲松', '11000276539.龚小乐', '11000281932.房昭强'], 'indvIsNew': '001', 'researcher': '范劲松,龚小乐,房昭强', 'newListingDate': '1996-09-27 00:00:00.000', 'newPurchaseDate': '1996-09-02 00:00:00.0', 'newIssuePrice': 8.48, 'newPeIssueA': '', 'indvAimPriceT': '', 'indvAimPriceL': '', 'attachType': '0', 'attachSize': 626, 'attachPages': 4, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cPF/r3LT13Jt2dzz0ywSmYk=', 'sRatingName': '买入', 'sRatingCode': '0104', 'market': 'SHENZHEN', 'authorID': ['11000236946', '11000276539', '11000281932'], 'count': 11, 'orgType': 'gray'}]
# [{'title': '差异化服务布局加速，新基本法赋能队伍转型，长期转型预期向好，叠加短期业绩大幅改善，积极推荐！', 'stockName': '中国太保', 'stockCode': '601601', 'orgCode': '80000124', 'orgName': '天风证券股份有限公司', 'orgSName': '天风证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439779715', 'column': '002004001003', 'predictNextTwoYearEps': '3.9100000000', 'predictNextTwoYearPe': '8.8700000000', 'predictNextYearEps': '3.3900000000', 'predictNextYearPe': '10.2300000000', 'predictThisYearEps': '2.6400000000', 'predictThisYearPe': '13.1200000000', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '474', 'indvInduName': '保险', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '007', 'lastEmRatingValue': '3', 'lastEmRatingName': '买入', 'ratingChange': 3, 'reportType': 2, 'author': ['11000284931.夏昌盛', '11000273337.罗钻辉'], 'indvIsNew': '001', 'researcher': '夏昌盛,罗钻辉', 'newListingDate': '2007-12-25 00:00:00.000', 'newPurchaseDate': '2007-12-14 00:00:00.0', 'newIssuePrice': 30.0, 'newPeIssueA': 35.84, 'indvAimPriceT': '', 'indvAimPriceL': '', 'attachType': '0', 'attachSize': 732, 'attachPages': 4, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cLYLd3fYYfzMbHXdu2Is4FI=', 'sRatingName': '买入', 'sRatingCode': '0201', 'market': 'SHANGHAI', 'authorID': ['11000284931', '11000273337'], 'count': 5, 'orgType': 'white'}]
# [{'title': '引入重组人促卵泡激素-CTP融合蛋白注射液，辅助生殖产品线进一步丰富', 'stockName': '长春高新', 'stockCode': '000661', 'orgCode': '10000296', 'orgName': '西南证券股份有限公司', 'orgSName': '西南证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439870481', 'column': '002004006003', 'predictNextTwoYearEps': '11.1600000000', 'predictNextTwoYearPe': '33.5300000000', 'predictNextYearEps': '9.1900000000', 'predictNextYearPe': '40.7400000000', 'predictThisYearEps': '7.2500000000', 'predictThisYearPe': '51.6200000000', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '465', 'indvInduName': '医药制造', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '007', 'lastEmRatingValue': '3', 'lastEmRatingName': '买入', 'ratingChange': 3, 'reportType': 2, 'author': ['11000254058.杜向阳', '11000279332.马云涛'], 'indvIsNew': '001', 'researcher': '杜向阳,马云涛', 'newListingDate': '1996-12-18 00:00:00.000', 'newPurchaseDate': '1996-12-03 00:00:00.0', 'newIssuePrice': 8.8, 'newPeIssueA': 13.33, 'indvAimPriceT': '', 'indvAimPriceL': '', 'attachType': '0', 'attachSize': 1146, 'attachPages': 4, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cNzKGOqWUVm9Oc3akaNTecQ=', 'sRatingName': '买入', 'sRatingCode': '0201', 'market': 'SHENZHEN', 'authorID': ['11000254058', '11000279332'], 'count': 3, 'orgType': 'gray'}, {'title': '大股东增持彰显信心，估值有望持续修复', 'stockName': '一心堂', 'stockCode': '002727', 'orgCode': '80000135', 'orgName': '中国银河证券股份有限公司', 'orgSName': '中国银河', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439824164', 'column': '002004006003', 'predictNextTwoYearEps': '1.8400000000', 'predictNextTwoYearPe': '22.0000000000', 'predictNextYearEps': '1.5080000000', 'predictNextYearPe': '27.0000000000', 'predictThisYearEps': '1.2400000000', 'predictThisYearPe': '33.0000000000', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '465', 'indvInduName': '医药制造', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '007', 'lastEmRatingValue': '3', 'lastEmRatingName': '买入', 'ratingChange': 3, 'reportType': 2, 'author': ['11000330431.孟令伟', '11000330432.刘晖'], 'indvIsNew': '001', 'researcher': '孟令伟,刘晖', 'newListingDate': '2014-07-02 00:00:00.000', 'newPurchaseDate': '2014-06-23 00:00:00.0', 'newIssuePrice': 12.2, 'newPeIssueA': 13.45, 'indvAimPriceT': '', 'indvAimPriceL': '', 'attachType': '0', 'attachSize': 949, 'attachPages': 9, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cODQOYDx/oAfOBI/qJ4j3dY=', 'sRatingName': '推荐', 'sRatingCode': '0104', 'market': 'SHENZHEN', 'authorID': ['11000330431', '11000330432'], 'count': 3, 'orgType': 'gray'}, {'title': '首次覆盖：深耕行业二十载，成就非强免猪苗龙头地位', 'stockName': '科前生物', 'stockCode': '688526', 'orgCode': '80000139', 'orgName': '西部证券股份有限公司', 'orgSName': '西部证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439820645', 'column': '002004001002', 'predictNextTwoYearEps': '1.5700000000', 'predictNextTwoYearPe': '', 'predictNextYearEps': '1.2900000000', 'predictNextYearPe': '40.0000000000', 'predictThisYearEps': '0.8800000000', 'predictThisYearPe': '', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '465', 'indvInduName': '医药制造', 'emRatingCode': '', 'emRatingValue': '', 'emRatingName': '', 'lastEmRatingCode': '', 'lastEmRatingValue': '', 'lastEmRatingName': '', 'ratingChange': '', 'reportType': 2, 'author': ['11000267032.刘菲', '11000256845.刘丛丛'], 'indvIsNew': '001', 'researcher': '刘菲,刘丛丛', 'newListingDate': '2020-09-22 00:00:00.000', 'newPurchaseDate': '2020-09-11 00:00:00.0', 'newIssuePrice': 11.69, 'newPeIssueA': 26.23, 'indvAimPriceT': '51.6000000000', 'indvAimPriceL': '51.6000000000', 'attachType': '0', 'attachS ...
# [{'title': '动态点评：半导体硅片领军者，积极布局功率和射频成长可期', 'stockName': '立昂微', 'stockCode': '605358', 'orgCode': '10001055', 'orgName': '国海证券股份有限公司', 'orgSName': '国海证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439846365', 'column': '002004006001', 'predictNextTwoYearEps': '0.9800000000', 'predictNextTwoYearPe': '123.0000000000', 'predictNextYearEps': '0.7300000000', 'predictNextYearPe': '165.0000000000', 'predictThisYearEps': '0.5000000000', 'predictThisYearPe': '239.0000000000', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '459', 'indvInduName': '电子元件', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '', 'lastEmRatingValue': '', 'lastEmRatingName': '', 'ratingChange': 2, 'reportType': 2, 'author': ['11000268832.吴吉森', '11000344334.何昊'], 'indvIsNew': '001', 'researcher': '吴吉森,何昊', 'newListingDate': '2020-09-11 00:00:00.000', 'newPurchaseDate': '2020-09-01 00:00:00.0', 'newIssuePrice': 4.92, 'newPeIssueA': 22.97, 'indvAimPriceT': '', 'indvAimPriceL': '', 'attachType': '0', 'attachSize': 627, 'attachPages': 5, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cKvRMJfHT7dHEc3ZH9ACGe4=', 'sRatingName': '买入', 'sRatingCode': '0104', 'market': 'SHANGHAI', 'authorID': ['11000268832', '11000344334'], 'count': 3, 'orgType': 'white'}, {'title': '投资价值分析报告：5G渗透、模组趋势和国产替代驱动中国射频前端平台型龙头的崛起', 'stockName': '卓胜微', 'stockCode': '300782', 'orgCode': '80000074', 'orgName': '光大证券股份有限公司', 'orgSName': '光大证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439833018', 'column': '002004001002', 'predictNextTwoYearEps': '11.4900000000', 'predictNextTwoYearPe': '51.0000000000', 'predictNextYearEps': '8.5500000000', 'predictNextYearPe': '69.0000000000', 'predictThisYearEps': '5.3400000000', 'predictThisYearPe': '111.0000000000', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '459', 'indvInduName': '电子元件', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '007', 'lastEmRatingValue': '3', 'lastEmRatingName': '买入', 'ratingChange': 3, 'reportType': 2, 'author': ['11000244526.刘凯'], 'indvIsNew': '001', 'researcher': '刘凯', 'newListingDate': '2019-06-18 00:00:00.000', 'newPurchaseDate': '2019-06-04 00:00:00.0', 'newIssuePrice': 35.29, 'newPeIssueA': 22.99, 'indvAimPriceT': '', 'indvAimPriceL': '', 'attachType': '0', 'attachSize': 20695, 'attachPages': 74, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cDsQwN5ts8YT8MVUeEWmRZQ=', 'sRatingName': '买入', 'sRatingCode': '0105', 'market': 'SHENZHEN', 'authorID': ['11000244526'], 'count': 1, 'orgType': 'gray'}, {'title': 'IGBT龙头，国产替代领军者', 'stockName': '斯达半导', 'stockCode': '603290', 'orgCode': '80000157', 'orgName': '中泰证券股份有限公司', 'orgSName': '中泰证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439777006', 'column': '002004001003', 'predictNextTwoYearEps': '1.9600000000', 'predictNextTwoYearPe': '139.0000000000', 'predictNextYearEps': '1.4600000000', 'predictNextYearPe': '187.0000000000', 'predictThisYearEps': '1.0800000000', 'predictThisYearPe': '251.0000000000', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '459', 'indvInduName': '电子元件', 'emRatingCode': '006', 'emRatingValue': '2', 'emRatingName': '增持', 'lastEmRatingCode': '', 'lastEmRatingValue': '', 'lastEmRatingName': '', 'ratingChange': 2, 'reportType': 2, 'author': ['11000288731.胡杨', '11000274740.张欣'], 'indvIsNew': '001', 'researcher': '胡杨,张欣', 'newListingDate': '2020-02-04 00:00:00.000', 'newPurchaseDate': '2020-01-15 00:00:00.0', 'newIssuePrice': 12.74, 'newPeIssueA': 22.98, 'indvAimPriceT': '', 'indvAimPriceL': '', 'attachType': '0', 'attachSize': 1163, 'attachPages': 11, ...
# [{'title': '硅片采购框架合同公告点评：加码“210”产能，主业有望迎来加速', 'stockName': '东方日升', 'stockCode': '300118', 'orgCode': '80000202', 'orgName': '华创证券有限责任公司', 'orgSName': '华创证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439899312', 'column': '002004006003', 'predictNextTwoYearEps': '1.8800000000', 'predictNextTwoYearPe': '10.0000000000', 'predictNextYearEps': '1.5100000000', 'predictNextYearPe': '13.0000000000', 'predictThisYearEps': '0.9500000000', 'predictThisYearPe': '20.0000000000', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '457', 'indvInduName': '输配电气', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '007', 'lastEmRatingValue': '3', 'lastEmRatingName': '买入', 'ratingChange': 3, 'reportType': 2, 'author': ['11000324242.杨达伟'], 'indvIsNew': '001', 'researcher': '杨达伟', 'newListingDate': '2010-09-02 00:00:00.000', 'newPurchaseDate': '2010-08-23 00:00:00.0', 'newIssuePrice': 42.0, 'newPeIssueA': 67.52, 'indvAimPriceT': '30.2000000000', 'indvAimPriceL': '30.2000000000', 'attachType': '0', 'attachSize': 795, 'attachPages': 4, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cFxi6zu+v1O2glIosThhqvo=', 'sRatingName': '强推', 'sRatingCode': '0104', 'market': 'SHENZHEN', 'authorID': ['11000324242'], 'count': 2, 'orgType': 'gray'}]
# [{'title': '赛伍技术：薄膜高分子平台型公司，横向拓展潜力无穷', 'stockName': '赛伍技术', 'stockCode': '603212', 'orgCode': '80092742', 'orgName': '信达证券股份有限公司', 'orgSName': '信达证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439854899', 'column': '002004001002', 'predictNextTwoYearEps': '1.5400000000', 'predictNextTwoYearPe': '23.3000000000', 'predictNextYearEps': '1.0100000000', 'predictNextYearPe': '35.6000000000', 'predictThisYearEps': '0.5000000000', 'predictThisYearPe': '72.0000000000', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '454', 'indvInduName': '塑胶制品', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '', 'lastEmRatingValue': '', 'lastEmRatingName': '', 'ratingChange': 2, 'reportType': 2, 'author': ['11000331534.武浩', '11000277040.陈磊'], 'indvIsNew': '001', 'researcher': '武浩,陈磊', 'newListingDate': '2020-04-30 00:00:00.000', 'newPurchaseDate': '2020-04-20 00:00:00.0', 'newIssuePrice': 10.46, 'newPeIssueA': 22.57, 'indvAimPriceT': '', 'indvAimPriceL': '', 'attachType': '0', 'attachSize': 1221, 'attachPages': 28, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cCcSw9hCdcevvG9ITlTncCY=', 'sRatingName': '买入', 'sRatingCode': '0101', 'market': 'SHANGHAI', 'authorID': ['11000331534', '11000277040'], 'count': 1, 'orgType': 'gray'}]
# [{'title': '重大事件快评：定增募资完成，开启新一轮增长', 'stockName': '新易盛', 'stockCode': '300502', 'orgCode': '80000007', 'orgName': '国信证券股份有限公司', 'orgSName': '国信证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439870483', 'column': '002004006003', 'predictNextTwoYearEps': '2.3400000000', 'predictNextTwoYearPe': '25.0000000000', 'predictNextYearEps': '1.9800000000', 'predictNextYearPe': '29.0000000000', 'predictThisYearEps': '1.3900000000', 'predictThisYearPe': '41.0000000000', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '448', 'indvInduName': '通讯行业', 'emRatingCode': '006', 'emRatingValue': '2', 'emRatingName': '增持', 'lastEmRatingCode': '006', 'lastEmRatingValue': '2', 'lastEmRatingName': '增持', 'ratingChange': 3, 'reportType': 2, 'author': ['11000197124.程成', '11000286535.马成龙'], 'indvIsNew': '001', 'researcher': '程成,马成龙', 'newListingDate': '2016-03-03 00:00:00.000', 'newPurchaseDate': '2016-02-23 00:00:00.0', 'newIssuePrice': 21.47, 'newPeIssueA': 18.58, 'indvAimPriceT': '', 'indvAimPriceL': '', 'attachType': '0', 'attachSize': 873, 'attachPages': 6, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cJhQRq69Kf8H0YrG9aN/4h0=', 'sRatingName': '增持', 'sRatingCode': '0202', 'market': 'SHENZHEN', 'authorID': ['11000197124', '11000286535'], 'count': 2, 'orgType': 'gray'}]
# [{'title': '份额提升与新业务再造一个新华三', 'stockName': '紫光股份', 'stockCode': '000938', 'orgCode': '80000073', 'orgName': '华泰证券股份有限公司', 'orgSName': '华泰证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439777004', 'column': '002004001002', 'predictNextTwoYearEps': '0.9900000000', 'predictNextTwoYearPe': '', 'predictNextYearEps': '0.8600000000', 'predictNextYearPe': '32.4600000000', 'predictThisYearEps': '0.6900000000', 'predictThisYearPe': '', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '447', 'indvInduName': '电子信息', 'emRatingCode': '006', 'emRatingValue': '2', 'emRatingName': '增持', 'lastEmRatingCode': '', 'lastEmRatingValue': '', 'lastEmRatingName': '', 'ratingChange': 2, 'reportType': 2, 'author': ['11000176312.王林', '11000258335.付东', '11000293734.余熠'], 'indvIsNew': '001', 'researcher': '王林,付东,余熠', 'newListingDate': '1999-11-04 00:00:00.000', 'newPurchaseDate': '1999-08-25 00:00:00.0', 'newIssuePrice': 11.75, 'newPeIssueA': 27.98, 'indvAimPriceT': '27.7600000000', 'indvAimPriceL': '27.7600000000', 'attachType': '0', 'attachSize': 2419, 'attachPages': 25, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cAhUla2XBymJgUYBvvdof2c=', 'sRatingName': '增持', 'sRatingCode': '0302', 'market': 'SHENZHEN', 'authorID': ['11000176312', '11000258335', '11000293734'], 'count': 1, 'orgType': 'white'}, {'title': '模拟IC细分领域龙头，国产替代空间广阔', 'stockName': '芯朋微', 'stockCode': '688508', 'orgCode': '80000157', 'orgName': '中泰证券股份有限公司', 'orgSName': '中泰证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439776991', 'column': '002004001003', 'predictNextTwoYearEps': '1.3800000000', 'predictNextTwoYearPe': '76.0000000000', 'predictNextYearEps': '1.0300000000', 'predictNextYearPe': '102.0000000000', 'predictThisYearEps': '0.7300000000', 'predictThisYearPe': '144.0000000000', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '447', 'indvInduName': '电子信息', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '', 'lastEmRatingValue': '', 'lastEmRatingName': '', 'ratingChange': 2, 'reportType': 2, 'author': ['11000288731.胡杨'], 'indvIsNew': '001', 'researcher': '胡杨', 'newListingDate': '2020-07-22 00:00:00.000', 'newPurchaseDate': '2020-07-13 00:00:00.0', 'newIssuePrice': 28.3, 'newPeIssueA': 52.16, 'indvAimPriceT': '', 'indvAimPriceL': '', 'attachType': '0', 'attachSize': 1848, 'attachPages': 16, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cIh1r63+TiHP52yQy3Cp8tI=', 'sRatingName': '买入', 'sRatingCode': '0104', 'market': 'SHANGHAI', 'authorID': ['11000288731'], 'count': 1, 'orgType': 'gray'}]
# [{'title': '粮油世家运营下的厨房食品航母', 'stockName': '金龙鱼', 'stockCode': '300999', 'orgCode': '80000007', 'orgName': '国信证券股份有限公司', 'orgSName': '国信证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439854929', 'column': '002004001002', 'predictNextTwoYearEps': '1.6300000000', 'predictNextTwoYearPe': '42.4000000000', 'predictNextYearEps': '1.5400000000', 'predictNextYearPe': '44.7000000000', 'predictThisYearEps': '1.4800000000', 'predictThisYearPe': '46.7000000000', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '438', 'indvInduName': '食品饮料', 'emRatingCode': '006', 'emRatingValue': '2', 'emRatingName': '增持', 'lastEmRatingCode': '', 'lastEmRatingValue': '', 'lastEmRatingName': '', 'ratingChange': 2, 'reportType': 2, 'author': ['11000257551.鲁家瑞'], 'indvIsNew': '001', 'researcher': '鲁家瑞', 'newListingDate': '2020-10-15 00:00:00.000', 'newPurchaseDate': '2020-09-25 00:00:00.0', 'newIssuePrice': 25.7, 'newPeIssueA': 31.12, 'indvAimPriceT': '', 'indvAimPriceL': '', 'attachType': '0', 'attachSize': 3218, 'attachPages': 37, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cP9TwIw/vFgisHx6GBkuNL8=', 'sRatingName': '增持', 'sRatingCode': '0202', 'market': 'SHENZHEN', 'authorID': ['11000257551'], 'count': 4, 'orgType': 'gray'}, {'title': '蒙牛入主，步入成长新阶段—公司复盘与展望', 'stockName': '妙可蓝多', 'stockCode': '600882', 'orgCode': '80084302', 'orgName': '安信证券股份有限公司', 'orgSName': '安信证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439824165', 'column': '002004006001', 'predictNextTwoYearEps': '1.5300000000', 'predictNextTwoYearPe': '31.0000000000', 'predictNextYearEps': '0.8400000000', 'predictNextYearPe': '57.0000000000', 'predictThisYearEps': '0.1600000000', 'predictThisYearPe': '', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '438', 'indvInduName': '食品饮料', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '', 'lastEmRatingValue': '', 'lastEmRatingName': '', 'ratingChange': 0, 'reportType': 2, 'author': ['11000232927.苏铖', '11000312737.徐哲琪'], 'indvIsNew': '001', 'researcher': '苏铖,徐哲琪', 'newListingDate': '1995-12-06 00:00:00.000', 'newPurchaseDate': '1988-12-15 00:00:00.0', 'newIssuePrice': 1.0, 'newPeIssueA': '', 'indvAimPriceT': '48.0000000000', 'indvAimPriceL': '48.0000000000', 'attachType': '0', 'attachSize': 2175, 'attachPages': 13, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cORAIf3Qr121Gl692fqvM2A=', 'sRatingName': '买入', 'sRatingCode': '0104', 'market': 'SHANGHAI', 'authorID': ['11000232927', '11000312737'], 'count': 6, 'orgType': 'white'}, {'title': '顺应行业趋势，产能逐步释放', 'stockName': '海欣食品', 'stockCode': '002702', 'orgCode': '80048595', 'orgName': '财通证券股份有限公司', 'orgSName': '财通证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439824163', 'column': '002004001002', 'predictNextTwoYearEps': '0.2800000000', 'predictNextTwoYearPe': '42.9000000000', 'predictNextYearEps': '0.2000000000', 'predictNextYearPe': '60.0000000000', 'predictThisYearEps': '0.1700000000', 'predictThisYearPe': '', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '438', 'indvInduName': '食品饮料', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '', 'lastEmRatingValue': '', 'lastEmRatingName': '', 'ratingChange': 2, 'reportType': 2, 'author': ['11000326534.刘骜飞'], 'indvIsNew': '001', 'researcher': '刘骜飞', 'newListingDate': '2012-10-11 00:00:00.000', 'newPurchaseDate': '2012-09-25 00:00:00.0', 'newIssuePrice': 29.0, 'newPeIssueA': 39.73, 'indvAimPriceT': '12.0000000000', 'indvAimPriceL': '12.0000000000', 'attachType': '0', 'attachSize': 2786, 'attachPages': 28, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cGHPgDz ...
# [{'title': '拟收购煤矿520万吨/年，公司资产实力进一步增强', 'stockName': '西山煤电', 'stockCode': '000983', 'orgCode': '80000157', 'orgName': '中泰证券股份有限公司', 'orgSName': '中泰证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439818181', 'column': '002004006003', 'predictNextTwoYearEps': '0.6500000000', 'predictNextTwoYearPe': '9.0000000000', 'predictNextYearEps': '0.6100000000', 'predictNextYearPe': '9.0000000000', 'predictThisYearEps': '0.4500000000', 'predictThisYearPe': '13.0000000000', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '437', 'indvInduName': '煤炭采选', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '007', 'lastEmRatingValue': '3', 'lastEmRatingName': '买入', 'ratingChange': 3, 'reportType': 2, 'author': ['11000250948.陈晨'], 'indvIsNew': '001', 'researcher': '陈晨', 'newListingDate': '2000-07-26 00:00:00.000', 'newPurchaseDate': '2000-07-06 00:00:00.0', 'newIssuePrice': 6.49, 'newPeIssueA': 33.8, 'indvAimPriceT': '', 'indvAimPriceL': '', 'attachType': '0', 'attachSize': 733, 'attachPages': 5, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cChYA32HFo9oN3O3FAYcmZo=', 'sRatingName': '买入', 'sRatingCode': '0104', 'market': 'SHENZHEN', 'authorID': ['11000250948'], 'count': 7, 'orgType': 'gray'}]
# [{'title': '白羽肉鸡养殖龙头蓄势转型，从“幕后”走向“台前”！', 'stockName': '圣农发展', 'stockCode': '002299', 'orgCode': '80000124', 'orgName': '天风证券股份有限公司', 'orgSName': '天风证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439776995', 'column': '002004001003', 'predictNextTwoYearEps': '3.1500000000', 'predictNextTwoYearPe': '9.0000000000', 'predictNextYearEps': '1.6400000000', 'predictNextYearPe': '17.0000000000', 'predictThisYearEps': '1.8000000000', 'predictThisYearPe': '16.0000000000', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '433', 'indvInduName': '农牧饲渔', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '', 'lastEmRatingValue': '', 'lastEmRatingName': '', 'ratingChange': 2, 'reportType': 2, 'author': ['11000174533.吴立', '11000305132.陈潇'], 'indvIsNew': '001', 'researcher': '吴立,陈潇', 'newListingDate': '2009-10-21 00:00:00.000', 'newPurchaseDate': '2009-10-09 00:00:00.0', 'newIssuePrice': 19.75, 'newPeIssueA': 44.89, 'indvAimPriceT': '57.4000000000', 'indvAimPriceL': '49.2000000000', 'attachType': '0', 'attachSize': 2136, 'attachPages': 18, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cHQSaDFW8VT9EE1HTas+iwg=', 'sRatingName': '买入', 'sRatingCode': '0201', 'market': 'SHENZHEN', 'authorID': ['11000174533', '11000305132'], 'count': 1, 'orgType': 'white'}]
# [{'title': '揽红星入怀，白酒板块再添新兵', 'stockName': '大豪科技', 'stockCode': '603025', 'orgCode': '80084302', 'orgName': '安信证券股份有限公司', 'orgSName': '安信证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439815256', 'column': '002004001002', 'predictNextTwoYearEps': '0.2400000000', 'predictNextTwoYearPe': '53.2000000000', 'predictNextYearEps': '0.2100000000', 'predictNextYearPe': '60.1000000000', 'predictThisYearEps': '0.1600000000', 'predictThisYearPe': '79.3000000000', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '910', 'indvInduName': '专用设备', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '', 'lastEmRatingValue': '', 'lastEmRatingName': '', 'ratingChange': 2, 'reportType': 2, 'author': ['11000232927.苏铖', '11000338351.孙瑜'], 'indvIsNew': '001', 'researcher': '苏铖,孙瑜', 'newListingDate': '2015-04-22 00:00:00.000', 'newPurchaseDate': '2015-04-14 00:00:00.0', 'newIssuePrice': 11.17, 'newPeIssueA': 22.98, 'indvAimPriceT': '', 'indvAimPriceL': '', 'attachType': '0', 'attachSize': 3057, 'attachPages': 21, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cJOxmAmXjB50XDhPFmiaDDU=', 'sRatingName': '买入', 'sRatingCode': '0104', 'market': 'SHANGHAI', 'authorID': ['11000232927', '11000338351'], 'count': 1, 'orgType': 'white'}]
# [{'title': '东睦股份点评：持续看好PM回暖，期待MIM整合效果逐步展现', 'stockName': '东睦股份', 'stockCode': '600114', 'orgCode': '80000206', 'orgName': '浙商证券股份有限公司', 'orgSName': '浙商证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439776993', 'column': '002004006003', 'predictNextTwoYearEps': '0.6200000000', 'predictNextTwoYearPe': '13.0000000000', 'predictNextYearEps': '0.4800000000', 'predictNextYearPe': '17.0000000000', 'predictThisYearEps': '0.1300000000', 'predictThisYearPe': '60.0000000000', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '739', 'indvInduName': '金属制品', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '007', 'lastEmRatingValue': '3', 'lastEmRatingName': '买入', 'ratingChange': 3, 'reportType': 2, 'author': ['11000177507.王华君'], 'indvIsNew': '001', 'researcher': '王华君', 'newListingDate': '2004-05-11 00:00:00.000', 'newPurchaseDate': '2004-04-19 00:00:00.0', 'newIssuePrice': 10.0, 'newPeIssueA': 13.89, 'indvAimPriceT': '', 'indvAimPriceL': '', 'attachType': '0', 'attachSize': 745, 'attachPages': 5, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cLWVYzyrduQaCI3mqP80oEg=', 'sRatingName': '买入', 'sRatingCode': '0103', 'market': 'SHANGHAI', 'authorID': ['11000177507'], 'count': 1, 'orgType': 'white'}]
# [{'title': '进入NCRE：占领用户心智的最高级方式', 'stockName': '金山办公', 'stockCode': '688111', 'orgCode': '80084302', 'orgName': '安信证券股份有限公司', 'orgSName': '安信证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439833010', 'column': '002004006003', 'predictNextTwoYearEps': '3.4000000000', 'predictNextTwoYearPe': '89.2000000000', 'predictNextYearEps': '2.5800000000', 'predictNextYearPe': '117.5000000000', 'predictThisYearEps': '1.8400000000', 'predictThisYearPe': '164.9000000000', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '737', 'indvInduName': '软件服务', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '007', 'lastEmRatingValue': '3', 'lastEmRatingName': '买入', 'ratingChange': 3, 'reportType': 2, 'author': ['11000172322.胡又文', '11000318735.黄净'], 'indvIsNew': '001', 'researcher': '胡又文,黄净', 'newListingDate': '2019-11-18 00:00:00.000', 'newPurchaseDate': '2019-11-07 00:00:00.0', 'newIssuePrice': 45.86, 'newPeIssueA': 78.37, 'indvAimPriceT': '', 'indvAimPriceL': '', 'attachType': '0', 'attachSize': 864, 'attachPages': 5, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cDixFpXtBsKp1CG8YCPrysE=', 'sRatingName': '买入', 'sRatingCode': '0104', 'market': 'SHANGHAI', 'authorID': ['11000172322', '11000318735'], 'count': 4, 'orgType': 'white'}, {'title': '公司信息更新报告：定增成功落地，优质投资机构认购彰显市场信心', 'stockName': '深信服', 'stockCode': '300454', 'orgCode': '80000162', 'orgName': '开源证券股份有限公司', 'orgSName': '开源证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012131439707589', 'column': '002004006001', 'predictNextTwoYearEps': '3.6300000000', 'predictNextTwoYearPe': '60.0000000000', 'predictNextYearEps': '2.8800000000', 'predictNextYearPe': '75.0000000000', 'predictThisYearEps': '2.2100000000', 'predictThisYearPe': '98.0000000000', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '737', 'indvInduName': '软件服务', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '007', 'lastEmRatingValue': '3', 'lastEmRatingName': '买入', 'ratingChange': 3, 'reportType': 2, 'author': ['11000225544.陈宝健', '11000341331.刘逍遥'], 'indvIsNew': '001', 'researcher': '陈宝健,刘逍遥', 'newListingDate': '2018-05-16 00:00:00.000', 'newPurchaseDate': '2018-05-07 00:00:00.0', 'newIssuePrice': 30.07, 'newPeIssueA': 22.99, 'indvAimPriceT': '', 'indvAimPriceL': '', 'attachType': '0', 'attachSize': 779, 'attachPages': 4, 'encodeUrl': 'xGtevV3JJCJIRkHnvYCPWy3hxAmxJY425prMeR35+Dc=', 'sRatingName': '买入( Buy)', 'sRatingCode': '0201', 'market': 'SHENZHEN', 'authorID': ['11000225544', '11000341331'], 'count': 4, 'orgType': 'gray'}]
# [{'title': '债权转让加速现金回笼，治理结构改善步稳蹄急', 'stockName': '赤峰黄金', 'stockCode': '600988', 'orgCode': '80084302', 'orgName': '安信证券股份有限公司', 'orgSName': '安信证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439820464', 'column': '002004001003', 'predictNextTwoYearEps': '1.5300000000', 'predictNextTwoYearPe': '', 'predictNextYearEps': '0.7700000000', 'predictNextYearPe': '30.0000000000', 'predictThisYearEps': '0.4700000000', 'predictThisYearPe': '', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '732', 'indvInduName': '贵金属', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '007', 'lastEmRatingValue': '3', 'lastEmRatingName': '买入', 'ratingChange': 3, 'reportType': 2, 'author': ['11000201325.齐丁', '11000322647.王政', '11000337135.王建润'], 'indvIsNew': '001', 'researcher': '齐丁,王政,王建润', 'newListingDate': '2004-04-14 00:00:00.000', 'newPurchaseDate': '2004-03-30 00:00:00.0', 'newIssuePrice': 9.08, 'newPeIssueA': 19.32, 'indvAimPriceT': '23.2000000000', 'indvAimPriceL': '23.2000000000', 'attachType': '0', 'attachSize': 884, 'attachPages': 5, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cFhoozn1Vi02WX72kg4/XrQ=', 'sRatingName': '买入', 'sRatingCode': '0104', 'market': 'SHANGHAI', 'authorID': ['11000201325', '11000322647', '11000337135'], 'count': 3, 'orgType': 'white'}]
# [{'title': 'Q3扣非业绩大幅增长，看好明年磷复肥景气复苏', 'stockName': '司尔特', 'stockCode': '002538', 'orgCode': '80000091', 'orgName': '东方证券股份有限公司', 'orgSName': '东方证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439779712', 'column': '002004006001', 'predictNextTwoYearEps': '0.5600000000', 'predictNextTwoYearPe': '', 'predictNextYearEps': '0.4500000000', 'predictNextYearPe': '16.0000000000', 'predictThisYearEps': '0.3800000000', 'predictThisYearPe': '', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '731', 'indvInduName': '化肥行业', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '007', 'lastEmRatingValue': '3', 'lastEmRatingName': '买入', 'ratingChange': 3, 'reportType': 2, 'author': ['11000313236.万里扬'], 'indvIsNew': '001', 'researcher': '万里扬', 'newListingDate': '2011-01-18 00:00:00.000', 'newPurchaseDate': '2011-01-06 00:00:00.0', 'newIssuePrice': 26.0, 'newPeIssueA': 63.41, 'indvAimPriceT': '7.2000000000', 'indvAimPriceL': '7.2000000000', 'attachType': '0', 'attachSize': 548, 'attachPages': 5, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cIVWAo+G52RNQIVgVNHiH3U=', 'sRatingName': '买入', 'sRatingCode': '0104', 'market': 'SHENZHEN', 'authorID': ['11000313236'], 'count': 1, 'orgType': 'gray'}]
# [{'title': '爱美客动态报告：颜值时代“黄金赛道”生长出的轻医美龙头', 'stockName': '爱美客', 'stockCode': '300896', 'orgCode': '80000038', 'orgName': '民生证券股份有限公司', 'orgSName': '民生证券', 'publishDate': '2020-12-14 00:00:00.000', 'infoCode': 'AP202012141439793695', 'column': '002004006001', 'predictNextTwoYearEps': '6.5800000000', 'predictNextTwoYearPe': '91.0000000000', 'predictNextYearEps': '4.6700000000', 'predictNextYearPe': '129.0000000000', 'predictThisYearEps': '3.4500000000', 'predictThisYearPe': '174.0000000000', 'predictLastYearEps': '', 'predictLastYearPe': '', 'actualLastTwoYearEps': '', 'actualLastYearEps': '', 'industryCode': '', 'industryName': '', 'emIndustryCode': '', 'indvInduCode': '727', 'indvInduName': '医疗行业', 'emRatingCode': '007', 'emRatingValue': '3', 'emRatingName': '买入', 'lastEmRatingCode': '', 'lastEmRatingValue': '', 'lastEmRatingName': '', 'ratingChange': 2, 'reportType': 2, 'author': ['11000261632.刘欣', '11000206140.钟奇'], 'indvIsNew': '001', 'researcher': '刘欣,钟奇', 'newListingDate': '2020-09-28 00:00:00.000', 'newPurchaseDate': '2020-09-17 00:00:00.0', 'newIssuePrice': 118.27, 'newPeIssueA': 47.9, 'indvAimPriceT': '', 'indvAimPriceL': '', 'attachType': '0', 'attachSize': 1687, 'attachPages': 18, 'encodeUrl': 'y0YtetPwXoIZnWq51nn4cPgUhdmQS9VDMVtCguKLhYI=', 'sRatingName': '推荐', 'sRatingCode': '0201', 'market': 'SHENZHEN', 'authorID': ['11000261632', '11000206140'], 'count': 9, 'orgType': 'gray'}]
# 24

# %%
未测试 
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
@author: 闲欢
"""
from urllib.request import quote
import requests
import random
import traceback
import time
import datetime
import math
import json
import pymysql

from stock import dateUtil


class report:

    def __init__(self):
        self.header = {"Connection": "keep-alive",
                       "Cookie": "st_si=30608909553535; cowminicookie=true; st_asi=delete; cowCookie=true; intellpositionL=2048px; qgqp_b_id=c941d206e54fae32beffafbef56cc4c0; st_pvi=19950313383421; st_sp=2020-10-19%2020%3A19%3A47; st_inirUrl=http%3A%2F%2Fdata.eastmoney.com%2Fstock%2Flhb.html; st_sn=15; st_psi=20201026225423471-113300303752-5813912186; intellpositionT=2579px",
                          "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.70 Safari/537.36",
                          "Host": "reportapi.eastmoney.com"
                          }

        self.conn = pymysql.connect(host='127.0.0.1', port=3306, user='root', passwd='root', db='east_money', charset='utf8')
        self.cur = self.conn.cursor()
        self.url = 'http://reportapi.eastmoney.com/report/list?cb=datatable1351846&industryCode=*&pageSize={}&industry=*&rating=&ratingChange=&beginTime={}&endTime={}&pageNo={}&fields=&qType=0&orgCode=&code=*&rcode=&p=2&pageNum=2&_=1603724062679'

    def getHtml(self, pageSize, beginTime, endTime, pageNo):
        print(self.url.format(pageSize, beginTime, endTime, pageNo))
        response = requests.get(self.url.format(pageSize, beginTime, endTime, pageNo), headers=self.header)
        html = response.content.decode("utf-8")

        return html

    def format_content(self, content):
        if len(content):
            content = content.replace('datatable1351846(', '')[:-1]
            return json.loads(content)
        else:
            return None


    def parse_data(self, items):
        result_list = []
        for i in items['data']:
            result = {}
            obj = i
            result['title'] = obj['title'] #报告名称
            result['stockName'] = obj['stockName'] #股票名称
            result['stockCode'] = obj['stockCode'] #股票code
            result['orgCode'] = obj['stockCode'] #机构code
            result['orgName'] = obj['orgName'] #机构名称
            result['orgSName'] = obj['orgSName'] #机构简称
            result['publishDate'] = obj['publishDate'] #发布日期
            result['predictNextTwoYearEps'] = obj['predictNextTwoYearEps'] #后年每股盈利
            result['predictNextTwoYearPe'] = obj['predictNextTwoYearPe'] #后年市盈率
            result['predictNextYearEps'] = obj['predictNextYearEps'] # 明年每股盈利
            result['predictNextYearPe'] = obj['predictNextYearPe'] # 明年市盈率
            result['predictThisYearEps'] = obj['predictThisYearEps'] #今年每股盈利
            result['predictThisYearPe'] = obj['predictThisYearPe'] #今年市盈率
            result['indvInduCode'] = obj['indvInduCode'] # 行业代码
            result['indvInduName'] = obj['indvInduName'] # 行业名称
            result['lastEmRatingName'] = obj['lastEmRatingName'] # 上次评级名称
            result['lastEmRatingValue'] = obj['lastEmRatingValue'] # 上次评级代码
            result['emRatingValue'] = obj['emRatingValue'] # 评级代码
            result['emRatingName'] = obj['emRatingName'] # 评级名称
            result['ratingChange'] = obj['ratingChange'] # 评级变动
            result['researcher'] = obj['researcher'] # 研究员
            result['encodeUrl'] = obj['encodeUrl'] # 链接
            result['count'] = int(obj['count']) # 近一月个股研报数

            result_list.append(result)

        return result_list


    def get_data(self, start_date, end_date):
        html = self.getHtml(100, start_date, end_date, 1)
        content_json = self.format_content(html)
        page_num = content_json['TotalPage']
        print(page_num)

        data_list = []
        for i in range(1, page_num + 1):
            ihtml = self.getHtml(100, start_date, end_date, i)
            icontent_json = self.format_content(ihtml)
            result_list = self.parse_data(icontent_json)
            data_list.extend(result_list)

            time.sleep(random.randint(1, 4))
        return data_list

    def deal(self, start_date, end_date):
        data_list = self.get_data(start_date, end_date)
        if data_list and data_list is not None:
            self.insertdb(data_list)

        self.cur.close()
        self.conn.close()

    def insertdb(self, data_list):
        attrs = ['title', 'stockName', 'stockCode', 'orgCode', 'orgName', 'orgSName', 'publishDate', 'predictNextTwoYearEps',
                 'predictNextTwoYearPe', 'predictNextYearEps', 'predictNextYearPe', 'predictThisYearEps', 'predictThisYearPe',
                 'indvInduCode', 'indvInduName', 'lastEmRatingName', 'lastEmRatingValue', 'emRatingValue',
                 'emRatingName', 'ratingChange', 'researcher', 'encodeUrl', 'count']
        insert_tuple = []
        for obj in data_list:
            insert_tuple.append((obj['title'], obj['stockName'], obj['stockCode'], obj['orgCode'], obj['orgName'], obj['orgSName'], obj['publishDate'], obj['predictNextTwoYearEps'], obj['predictNextTwoYearPe'], obj['predictNextYearEps'], obj['predictNextYearPe'], obj['predictThisYearEps'], obj['predictThisYearPe'], obj['indvInduCode'], obj['indvInduName'], obj['lastEmRatingName'], obj['lastEmRatingValue'], obj['emRatingValue'],obj['emRatingName'], obj['ratingChange'], obj['researcher'], obj['encodeUrl'], obj['count']))
        values_sql = ['%s' for v in attrs]
        attrs_sql = '('+','.join(attrs)+')'
        values_sql = ' values('+','.join(values_sql)+')'
        sql = 'insert into %s' % 'report'
        sql = sql + attrs_sql + values_sql
        try:
            print(sql)
            for i in range(0, len(insert_tuple), 20000):
                self.cur.executemany(sql, tuple(insert_tuple[i:i+20000]))
                self.conn.commit()
        except pymysql.Error as e:
            self.conn.rollback()
            error = 'insertMany executemany failed! ERROR (%s): %s' % (e.args[0], e.args[1])
            print(error)


if __name__ == "__main__":
    report = report()
    today = dateUtil.DateUtil.get_today()
    one_year_before = dateUtil.DateUtil.get_format_day(dateUtil.DateUtil.get_minus_time(datetime.datetime.now(), days=365), '%Y-%m-%d')
    report.deal(one_year_before, today)
